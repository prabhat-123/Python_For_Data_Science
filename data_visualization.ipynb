# %% [markdown]
# # Data Visualization
#
# <li>Data Visualization is the process of presenting data in the form of graphs or charts.</li>
# <li>Data visualisation is an essential part of any data analysis or machine learning workflow. It allows to gain insights about our data.</li>
# <li>As the famous saying suggests, 'a picture is worth a thousand words'.</li>
# <li>It helps to understand large and complex amounts of data very easily.</li>
# <li>It allows the decision-makers to make decisions very efficiently and also allows them in identifying new trends and patterns very easily.</li>
# <li>It is also used in high-level data analysis for Machine Learning and Exploratory Data Analysis (EDA).</li>
# <li>At the heart of any data science workflow is data exploration. Most commonly, we explore data by using the following:</li>
# <ol>
#     <li>Statistical methods (measuring averages, measuring variability, etc.)</li>
#     <li>Data visualization (transforming data into a visual form)</li>
# </ol>
#
# <li>This indicates that one of the central tasks of data visualization is to help us explore data.</li>
# <li>The other central task is to help us communicate and explain the results we've found through exploring data.</li>
# <li>That being said, we have two kinds of data visualization:</li>
# <ol>
#     <li><b>Exploratory data visualization:</b> we build graphs for ourselves to explore data and find patterns.</li>               <li><b>Explanatory data visualization:</b> we build graphs for others to communicate and explain the patterns we've found through exploring data.</li>
# </ol>
# <li>Data visualization can be done with various tools like Tableau, Power BI, Matplotlib, Plotly, Seaborn.</li>
# <li>Here, we are going to learn about matplotlib and seaborn.</li>

# %% [markdown]
# ## Matplotlib
# <li>Matplotlib is a Python library specifically designed for creating visualizations.</li>
# <li>Matplotlib is open source and we can use it freely.</li>
# <li>It is a cross-platform library for making 2D plots from data in arrays.</li>
# <li>It provides an object-oriented API that helps in embedding plots in applications using Python GUI toolkits such as PyQt, Tkinter.</li>
# <li>It can be used in Python and IPython shells, Jupyter notebook and web application servers also.</li>
# <li>The various plots we can utilize using matplotlib are: </li>
# <ol>
#     <b><li>Line Plot</li></b>
#     <b><li>Histogram</li></b>
#     <b><li>Bargraph</li></b>
#     <b><li>Pie Chart.</li></b>
#     <b><li>Scatter Plot</li></b>
#     <b><li>Box Plot</li></b>
#     <b><li>Distribution plot</li></b>
#     <b><li>3D Plot</li></b>
#     <b><li>Image</li></b>
# </ol>

# %% [markdown]
# ## Installation Of Matplotlib
# <li>Go to your terminal, open and activate your virtual environment and then use the following commands for installing matplotlib.</li>
# <code>
#     pip install matplotlib
# </code>
#
#
# ## Importing Matplotlib
# <li>We need to import matplotlib if we want to create any visualization graphs.</li>
# <li>We can import matplotlib package using the following command:</li>
# <code>
# import matplotlib.pyplot as plt
# </code>

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Coordinate Systems In A Graph
#
# <li>We can create a graph by drawing two lines at right angles to each other.</li>
# <li>Each line is called an axis — the horizontal line at the bottom is the x-axis, and the vertical line on the left is the y-axis.</li>
# <li>The point where the two lines intersect is called the origin.</li>
#
# ![](images/axis_and_origin.png)

# %% [markdown]
# <li>Each axis has length — below, we see both axes marked with numbers, which represent unit lengths.</li>
#
# ![](images/unit_distance_from_axis.png)

# %% [markdown]
# <li>The length of the axes helps us precisely locate any point drawn on the graph.</li>
# <li>Point A on the graph below, for instance, is seven length units away from the y-axis and two units away from the x-axis.</li>
# <li>The x-coordinate shows the distance in unit lengths relative to the y-axis.</li>
# <li>The y-coordinate shows the distance in unit lengths relative to the x-axis.</li>
#
# ![](images/coordinate_system.png)

# %% [markdown]
# ## Interpret the following graph
#
# ![](images/coordinate_system_question.png)
# <ol>
#     <li>What is the unit length of the x-axis? Assign your answer to x_unit_length.</li>
#     <li>What is the unit length of the y-axis? Assign your answer to y_unit_length.</li>
#     <li>What is x-coordinate of point A? Assign your answer to x_coordinate_A.</li>
#     <li>What is the y-coordinate of point B? Assign your answer to y_coordinate_B.</li>
# <li>What are the x- and y-coordinates of point C? Assign your answer as a Python list to C_coordinates — the x-coordinate must come first in your list.</li>
# </b>

# %% [markdown]
# ## 1. Lineplot
# <li>To create our line plot graph above, we need to:</li>
# <ol>
#     <li>Add the data to the plt.plot() function.</li>
#     <li>The data should represent the coordinate systems data.</li>
#     <li>x-coordinates and y-coordinates values should be passed separately in two different lists.</li>
#     <li>Display the plot using the plt.show() function.</li>
#
# </ol>

# %% [markdown]
# ## Covid19 deaths according to months
# month_number = [1, 2, 3, 4, 5, 6, 7]
#
# new_deaths = [213, 2729, 37718, 184064, 143119, 136073, 165003]

# %%
month_number = [1, 2, 3, 4, 5, 6, 7]
new_deaths = [213, 2729, 37718, 184064, 143119, 136073, 165003]

# %%
plt.plot(month_number, new_deaths)

# %% [markdown]
# ## Question:
#
# <li>Read cricket_scores.csv and load it into a pandas dataframe.</li>
# <li>Extract the scores and overs details when Newzeland was batting.</li>
# <li>Create a lineplot to show the scores scored by Newzeland in each over.</li>
# <li>In the x-axis, we have to include the overs while in y-axis, you have to include the scores.</li>

# %%
import pandas as pd
scores_df = pd.read_csv('csv_data/cricket_scores.csv')

# %%
scores_df.head()
# Out:
#   Batting_team  Run  Over  Wickets
# 0    Newzeland    6   1.0        0
# 1    Newzeland   10   2.0        0
# 2    Newzeland   21   3.0        0
# 3    Newzeland   21   4.0        1
# 4    Newzeland   29   5.0        2

# %%
scores_df.tail()
# Out:
#    Batting_team  Run  Over  Wickets
# 35        India   77  16.0        4
# 36        India   82  17.0        4
# 37        India   87  18.0        4
# 38        India   94  19.0        4
# 39        India  101  19.5        4

# %%
nz_score = scores_df.loc[scores_df['Batting_team'] == "Newzeland"]
nz_score.shape
# Out:
# (20, 4)

# %%
nz_over_list = nz_score['Over']
nz_run_list = nz_score['Run']

# %%
plt.plot(nz_over_list, nz_run_list)

# %% [markdown]
# ## Customizing a graph
#
# <li>To give the title to the plot we can use <b>plt.title()</b> and add title details inside.</li>
# <li>Similarly, we can also give names to the coordinate axes using <b>plt.xlabel()</b> and <b>plt.ylabel().</b></li>
# <li>You can also use <b>marker</b> and <b>markersize</b> parameters if you also want to highlight the coordinate points while creating line graph plot.</li>

# %%
plt.plot(month_number, new_deaths, marker = 'o')
plt.title('Covid19 Deaths Toll Rising')
plt.xlabel('Months in Number')
plt.ylabel('Number of New Deaths')
plt.show()

# %% [markdown]
# ## Instructions
# <li>Add title to the newzeland score per over line plot.</li>
# <li>Also provide the xlabel and ylabel accordingly.</li>
# <li>Experiment with marker and markersize parameter to highlight scores in each over.</li>

# %%
plt.plot(nz_over_list, nz_run_list, marker = 'o', markersize = 5)
plt.title('Newzeland scores in 2nd T20 cricket')
plt.xlabel('No of overs')
plt.ylabel('Runs Scored')
plt.show()

# %% [markdown]
# ## Visualizing time series data using line graph
# <li>Time-series data is a sequence of data points collected over time intervals, allowing us to track changes over time.</li> <li>Time-series data can track changes over milliseconds, days, or even years.</li>
# <li>Typically we visualize time series with line graphs. The time values are always plotted, by convention, on the x-axis.</li>
#
# <b>Use 'AirPassengers.csv' data</b>

# %%
air_df = pd.read_csv('csv_data/AirPassengers.csv')
air_df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
plt.plot(air_df['Month'], air_df['#Passengers'], marker = 'o')
plt.title("Air Passengers traffic over years")
plt.xlabel('Year and Months')
plt.ylabel('No of Passengers')
plt.show()

# %% [markdown]
# ### Growth over time and thier graphs
# <li>Generally, a quantity that increases very quickly in the beginning — and then it slows down more and more over time — has a logarithmic growth.</li>
# <li>Generally, a quantity that increases slowly in the beginning — but then starts growing faster and faster over time — has exponential growth.</li>
# <li>Generally, a quantity that increases constantly over time has linear growth.</li>
# <li>To sum up, these are the three types of growth we've learned in this session:</li>
#
# ![](images/types_of_graph.png)

# %%
import numpy as np

# %%
df = pd.DataFrame({"normal": [i for i in range(1, 11)],
                  "square": [i* i for i in range(1, 11)],
                  "cube": [i**3 for i in range(1, 11)],
                  "log": [np.log(i) for i in range(1, 11)],
                  "linear": [i + 3 for i in range(1, 11)]})
df.head()
# Out:
#    normal  square  cube       log  linear
# 0       1       1     1  0.000000       4
# 1       2       4     8  0.693147       5
# 2       3       9    27  1.098612       6
# 3       4      16    64  1.386294       7
# 4       5      25   125  1.609438       8

# %%
plt.plot(df['normal'], df['linear'], marker = 'o')
plt.show()

# %%
plt.plot(df['normal'], df['square'], marker = 'o')
plt.show()

# %%
plt.plot(df['normal'], df['cube'], marker = 'o')
plt.show()

# %%
plt.plot(df['normal'], df['log'], marker = 'o')
plt.show()

# %% [markdown]
# <li>Change is not only about growth.</li>
# <li>A quantity can also decrease following a linear, exponential, or logarithmic pattern.</li>
#
# ![](images/negative_growth_graph.png)

# %%
downtrend_df = pd.DataFrame({"normal": [i for i in range(1, 11)],
                  "square": [i* i for i in range(11, 1, -1)],
                  "cube": [i**3 for i in range(11, 1, -1)],
                  "log": [np.log(i) for i in range(11, 1, -1)],
                  "linear": [i + 3 for i in range(11, 1, -1)]})
downtrend_df.head()
# Out:
#    normal  square  cube       log  linear
# 0       1     121  1331  2.397895      14
# 1       2     100  1000  2.302585      13
# 2       3      81   729  2.197225      12
# 3       4      64   512  2.079442      11
# 4       5      49   343  1.945910      10

# %%
plt.plot(downtrend_df['normal'], downtrend_df['linear'], marker = 'o')
plt.show()

# %%
plt.plot(downtrend_df['normal'], downtrend_df['square'], marker = 'o')
plt.show()

# %%
plt.plot(downtrend_df['normal'], downtrend_df['cube'], marker = 'o')
plt.show()

# %%
plt.plot(downtrend_df['normal'], downtrend_df['log'], marker = 'o')
plt.show()

# %% [markdown]
# <li>In practice, most of the line graphs we plot don't show any clear pattern.</li>
# <li>We need to pay close attention to what we see and try to extract meaning without forcing the data into some patterns we already know.</li>
# <li>When we see irregularities on a line graph, this doesn't mean we can't extract any meaning.</li>
# <li>By analyzing the irregularities, we can sometimes uncover interesting details.</li>
#
# ![](images/irregular_graph.png)

# %%
random_df = pd.DataFrame({"normal": [i for i in range(1, 11)],
                         "random": np.random.randint(1, 1000, 10)})
random_df.head()
# Out:
#    normal  random
# 0       1     900
# 1       2     843
# 2       3     282
# 3       4     115
# 4       5     913

# %%
plt.plot(random_df['normal'], random_df['random'], marker = 'o')
plt.show()

# %% [markdown]
# ## Comparing graphs
# <li>If we want to compare the rate of quantity change with respect to another variable then we can create two line plots and visualize it.</li>
# <li>Don't forget to use label parameter inside plt.plot() if you are creating two line plots in a same graph.</li>
# <li>Incase you are plotting two line plots in same graph, you can give colors to each line plot using color parameter inside plt.plot() function.</li>
# <li>You can also add legend in a graph using plt.legend() but make sure you have supplied label.</li>

# %%
import matplotlib.pyplot as plt

# %%
x = ["January", "February", "March", "April", "May", "June", "July", "August",
    "September", "October", "November", "December"]
actual_sales = [100000, 123000, 118000, 128000, 135000, 142000, 112000, 118100,
               121500, 125000, 134000, 113000]
predicted_sales = [100100, 120000, 119000, 132000, 140000, 148000, 110000,
                   111500, 119500, 123000, 140000, 121000]

# %%
plt.plot(x, actual_sales, marker = 'o', color = "red")
plt.plot(x, predicted_sales, marker = 'o', color = 'green')
plt.title("Actual Vs Predicted Sales Over 8 months periods")
plt.xlabel("Months")
plt.xticks(rotation = 45)
plt.ylabel("Sales in 000s")
plt.show()

# %%
import pandas as pd
scores_df = pd.read_csv('csv_data/cricket_scores.csv')
scores_df.head()
# Out:
#   Batting_team  Run  Over  Wickets
# 0    Newzeland    6   1.0        0
# 1    Newzeland   10   2.0        0
# 2    Newzeland   21   3.0        0
# 3    Newzeland   21   4.0        1
# 4    Newzeland   29   5.0        2

# %%
nz_scores = scores_df.loc[scores_df['Batting_team'] == "Newzeland"]
ind_scores = scores_df.loc[scores_df['Batting_team'] == "India"]
print(nz_scores.shape)
print(nz_scores.shape)
# Out:
# (20, 4)
# (20, 4)

# %%
plt.plot(nz_scores['Over'], nz_scores['Run'], marker = 'o', color = 'black')
plt.plot(ind_scores['Over'], ind_scores['Run'], marker = 'o', color = 'blue')
plt.title("Ind Vs Nz 2nd Odi Scores")
plt.xlabel('Overs')
plt.ylabel("Runs Scored")
plt.show()

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
nz_scores['fow'] = nz_scores['Wickets'].diff()
nz_scores= nz_scores.fillna(0)
nz_scores
# Out:
#    Batting_team  Run  Over  Wickets  fow
# 0     Newzeland    6   1.0        0  0.0
# 1     Newzeland   10   2.0        0  0.0
# 2     Newzeland   21   3.0        0  0.0
# 3     Newzeland   21   4.0        1  1.0
# 4     Newzeland   29   5.0        2  1.0
# 5     Newzeland   33   6.0        2  0.0
# 6     Newzeland   35   7.0        3  1.0
# 7     Newzeland   40   8.0        3  0.0
# 8     Newzeland   45   9.0        3  0.0
# 9     Newzeland   48  10.0        4  1.0
# 10    Newzeland   54  11.0        4  0.0
# 11    Newzeland   58  12.0        4  0.0
# 12    Newzeland   62  13.0        5  1.0
# 13    Newzeland   67  14.0        5  0.0
# 14    Newzeland   71  15.0        5  0.0
# 15    Newzeland   76  16.0        5  0.0
# 16    Newzeland   80  17.0        6  1.0
# 17    Newzeland   83  18.0        8  2.0
# 18    Newzeland   94  19.0        8  0.0
# 19    Newzeland   99  20.0        8  0.0

# %%
nz_scores_fow = nz_scores.loc[nz_scores['fow'] > 0]
nz_scores_fow
# Out:
#    Batting_team  Run  Over  Wickets  fow
# 3     Newzeland   21   4.0        1  1.0
# 4     Newzeland   29   5.0        2  1.0
# 6     Newzeland   35   7.0        3  1.0
# 9     Newzeland   48  10.0        4  1.0
# 12    Newzeland   62  13.0        5  1.0
# 16    Newzeland   80  17.0        6  1.0
# 17    Newzeland   83  18.0        8  2.0

# %%
fow_dict = {'Run': [], 'Over': [], 'fow': []}
for item in nz_scores_fow.values:
    fow_dict['Run'].append(item[1])
    fow_dict['Over'].append(item[2])
    fow_dict['fow'].append(item[-1])

# %%
len(fow_dict['fow'])
# Out:
# 7

# %%
plt.plot(nz_scores['Over'], nz_scores['Run'], color = 'black')
plt.scatter(fow_dict['Over'], fow_dict['Run'], color = 'red')
for i in range(len(fow_dict['fow'])):
    plt.text(fow_dict['Over'][i], fow_dict['Run'][i] + 2, str(fow_dict['fow'][i]))
plt.title("Ind Vs Nz 2nd Odi Scores")
plt.xlabel('Overs')
plt.ylabel("Runs Scored")
plt.show()

# %% [markdown]
# ## Question
#
# <li>Load the dataset from <b>'bike_rental_datasets.csv'</b> and create a pandas dataframe out of it</li>
# <li>Plot two line graphs sharing the same x- and y-axis.</li>
# <li>For the first graph, plot the <b>dteday</b> column on the x-axis and the <b>casual</b> column on the y-axis.</li>
# <li>For the second graph, plot <b>dteday</b> on the x-axis and <b>registered</b> on the y-axis.</li>
# <li>Rotate the <b>x-ticks</b> to an angle of 30 degrees using <b>plt.xticks()</b>.</li>
# <li>Add the label <b>'Bikes Rented'</b> to the y-axis using <b>plt.ylabel()</b>.</li>
# <li>Add the label <b>'Date'</b> to the x-axis using <b>plt.xlabel()</b>.</li>
# <li>Add the title <b>'Bikes Rented: Casual vs. Registered'</b> using <b>plt.title()</b>.</li>
# <li>Add a legend using <b>plt.legend()</b>. Use <b>'Casual'</b> and <b>'Registered'</b> as labels.</li>
# <li>What differences and similarities do you see for the two line graphs?</li>

# %%
bike_df = pd.read_csv('csv_data/bike_rental_datasets.csv')
bike_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bike_df.shape
# Out:
# (17379, 17)

# %%
bike_df['dteday'] = pd.to_datetime(bike_df['dteday'])

# %%
bike_df.set_index('dteday', inplace = True)

# %%
bike_df.head()
# Out:
#             instant  season  yr  mnth  hr  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1   0        0        6           0
# 2011-01-01        2       1   0     1   1        0        6           0
# 2011-01-01        3       1   0     1   2        0        6           0
# 2011-01-01        4       1   0     1   3        0        6           0
# 2011-01-01        5       1   0     1   4        0        6           0
#
#             weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# dteday
# 2011-01-01           1  0.24  0.2879  0.81        0.0       3          13   16
# 2011-01-01           1  0.22  0.2727  0.80        0.0       8          32   40
# 2011-01-01           1  0.22  0.2727  0.80        0.0       5          27   32
# 2011-01-01           1  0.24  0.2879  0.75        0.0       3          10   13
# 2011-01-01           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bike_df_day = bike_df.resample('D').mean()

# %%
bike_df_day.reset_index(inplace = True)
bike_df_day.shape
# Out:
# (731, 17)

# %%
plt.plot(bike_df_day['dteday'], bike_df_day['casual'], color = 'green',
        label = "Casual")
plt.plot(bike_df_day['dteday'], bike_df_day['registered'], color = 'red',
        label = "Registered")
plt.xticks(rotation = 45)
plt.title("Bikes Rented: Casual vs. Registered'")
plt.xlabel("Dates")
plt.ylabel("Bikes Rented")
plt.legend()
plt.show()

# %% [markdown]
# ## Seasonality In Time Series
#
# <li>Looking at the entire two-year period, we see the number of rented bikes is at its lowest during the winter months and at its highest during the summer</li>
# <li>Capital Bikeshare operates only in the northern hemisphere, so the summer months are June-August, and the winter months are December-February.</li>
#
# <li>In fact, we see quite a few similar patterns for both 2011 and 2012 with respect to the number of rented bikes:</li>
# <ol>
#     <li>The number keeps increasing in the January-May interval.</li>
#     <li>We see a plateau in the May-September interval, where the number of rentals stays high but constant (it neither increases nor decreases very much).</li>
#     <li>The number keeps decreasing in the September-December interval.</li>
# </ol>
#
# <li>We call all of these similarities seasonal trends.</li>
# <li>In time series data, we sometimes see specific patterns occurring regularly at specific intervals of time — we call this seasonality.</li>
# <li>Weather, holidays, school vacations and other factors can often cause seasonality.</li>
# <li>One popular example is ice-cream sales seasonality, sales are high during summer and low during winter.</li>

# %% [markdown]
# ## Identifying seasonality can be useful for businesses:
#
# <li>They can plan marketing campaigns at the right time.</li>
# <li>They don't need to panic needlessly when the sales are decreasing as a result of seasonality.</li>
# <li>They can hire extra employees right before the period of high activity begins.</li>

# %% [markdown]
# ## Stationary Graph In Time Series

# %%
bike_df_day['casual_df'] = bike_df_day['casual'].diff()
bike_df_day['casual_df_mv'] = bike_df_day['casual'].rolling(120).mean()

# %%
plt.plot(bike_df_day['dteday'], bike_df_day['casual_df'], color = 'green',
        label = "Casual Df")
plt.plot(bike_df_day['dteday'], bike_df_day['casual_df_mv'], color = 'red',
        label = "Casual Df")

# %% [markdown]
# ### Question
# <li>Create line graphs for temperature and dteday to see how temperature changes in each season</li>

# %% [markdown]
# ## Seaborn
# <li>Seaborn is a Python data visualization library based on matplotlib.</li>
# <li>It is built on the top of matplotlib library and also closely integrated to the data structures from pandas.</li>
# <li>It provides a high-level interface for drawing attractive and informative statistical graphics.</li>
# <li>It provides beautiful default styles and color palettes to make statistical plots more attractive.</li>

# %% [markdown]
# ### Installation Of Seaborn
# <li>Go to your terminal, open and activate your virtual environment and then use the following commands for installing seaborn.</li>
# <code>
#     pip install seaborn
# </code>
#
#
# ## Importing seaborn
# <li>We need to import seaborn if we want to create any visualization graphs.</li>
# <li>We can import seaborn package using the following command:</li>
# <code>
# import seaborn as sns
# </code>

# %%
import seaborn as sns

# %% [markdown]
# ### Histogram
# <li>A histogram is a graph showing frequency distributions.</li>
# <li>It is a graph showing the number of observations within each given interval.</li>
# <li>In Matplotlib, we use the plt.hist() function to create histograms.</li>
# <li>The <b>hist()</b> function will use an array of numbers to create a histogram, the array is sent into the function as an argument.</li>
# <li>We can also use seaborn to create a histogram plot.</li>
# <li>In seaborn, we have to use <b>histplot()</b> function inorder to create a histogram plot.</li>

# %%
import matplotlib.pyplot as plt

# %%
marks = [10, 20, 30 , 40, 50, 20 , 20, 33, 12, 45, 23, 16]
plt.hist(marks)
plt.show()

# %%
sns.histplot(marks)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
import pandas as pd
car_df = pd.read_csv('csv_data/car_details.csv')
car_df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
plt.figure(figsize = (4, 4))
plt.hist(car_df['selling_price'], color = 'green')
plt.ticklabel_format(style = 'plain')
plt.xticks(rotation = 30)
plt.title("Selling Price Distribution of Cars")
plt.xlabel('Price in rupees')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (6,6))
sns.histplot(car_df['km_driven'], color = 'red', kde = True)
plt.title("Km Driven Stats of different cars")
plt.xticks(rotation = 45)
plt.show()
plt.savefig('km_driven_stats.png')

# %% [markdown]
# ## Question
#
# <li>Generate a histogram for the casual column.</li>
# <li>Try to make a few quick observations about the histogram.</li>
# <li>What's the approximate range?</li>
# <li>What's the interval with the greatest frequency?</li>
# <li>What's the interval with the lowest frequency?</li>

# %%
import pandas as pd
bike_df = pd.read_csv('csv_data/bike_rental_datasets.csv')
bike_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
plt.figure(figsize = (6,6))
plt.hist(bike_df['casual'], color = 'black')
plt.title("Casual Bike Rentals THis Year")
plt.xlabel('(NO of bikes rented)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (10, 10))
sns.histplot(bike_df['casual'], kde = True)
plt.title("Casual Bike Rentals THis Year")
plt.xlabel('(NO of bikes rented)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Distribution Plots
#
# <li>It's useful to examine the shape of a histogram because it shows us the distribution of the values.</li>
# <li>We often see histograms with a shape that is more or less symmetrical.</li>
# <li>If we draw a vertical line exactly in the middle of a symmetrical histogram, then we divide the histogram in two halves that are mirror images of one another.</li>
# <li>A histogram shows the distribution of the values, and if its shape is symmetrical, then we say we have a symmetrical distribution.</li>
# <li>One common symmetrical distribution is the normal distribution (also called Gaussian distribution).</li>
#
#
# ![](images/symmetric_distribution.png)

# %%
import numpy as np
a = np.random.normal(loc = 20, scale = 1, size = 100)
plt.hist(a)
plt.show()

# %%
sns.histplot(a, kde = True, stat = 'density')
sns.kdeplot(a, color = 'green')
plt.show()

# %%
sns.distplot(a)
plt.show()
# Out:
# C:\Users\srval\AppData\Local\Temp\ipykernel_6240\2208103746.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a)

# %% [markdown]
# ### Normal Distribution
# <li>A normal distribution is a type of continuous probability distribution in which most data points cluster toward the middle of the range.</li>
# <li>While the rest taper off symmetrically toward either extreme. The middle of the range is also known as the mean of the distribution.</li>
# <li>Most of the values in that column lie in the middle of the range.</li>
# <li>As we approach the minimum and the maximum points of the range, we have less and less of those values.</li>
#
# ![](images/normal_dist2.png)

# %% [markdown]
# ### Uniform Distribution
#
# <li>Another symmetrical distribution we can see in practice is the uniform distribution</li>
# <li>The values are uniformly distributed. The bars have equal height because the intervals have equal frequencies.</li>
# <li>When we plot histograms in practice, we rarely see perfectly symmetrical distributions.</li>
# <li>However, these ideal cases we learned about serve as a baseline to help us describe and interpret the distributions we see in practice.</li>
#
# ![](images/uniform_distribution.png)

# %%
values = [56, 56, 55, 55, 54, 54, 57, 57, 58, 53,58, 52, 53, 52, 54, 59, 59]
sns.histplot(values)
plt.show()

# %%
uniform_array = np.random.uniform(low = 20, high = 60, size = 100)
sns.histplot(uniform_array, kde = True)
plt.show()

# %% [markdown]
# ### Skewed Distribution
#
# <li>Not all histogram shapes are symmetrical though.</li>
# <li>In a skewed distribution, we see the following:</li>
# <ol>
#     <li>The values pile up toward the end or the starting point of the range, making up the body of the distribution.</li>
#     <li>Then the values decrease in frequency towards the opposite end, forming the tail of the distribution.</li>
# </ol>
#
#
# <li>If the tail points to the right, then the distribution is right skewed.</li>
# <li>If the tail points to the left, then the distribution is said to be left skewed.</li>
#
#
#
# <li>When the tail points to the left, it also points in the direction of negative numbers (on the x-axis, the numbers decrease from right to left).</li>
# <li>For this reason, a left-skewed distribution is sometimes also said to have a negative skew.</li>
#
# <li>When the tail points to the right, it also points in the direction of positive numbers. As a consequence, right-skewed distributions are also said to have a positive skew.</li>
#
#
# ![](images/skewed_distribution.png)

# %%
sns.histplot(car_df['selling_price'])
mean = car_df['selling_price'].mean()
median = car_df['selling_price'].median()
print("Mean is {}".format(mean))
print("Median is {}".format(median))
plt.show()
# Out:
# Mean is 504127.3117511521
# Median is 350000.0

# %%
sns.histplot(car_df['year'])
mean = car_df['year'].mean()
median = car_df['year'].median()
print("Mean is {}".format(mean))
print("Median is {}".format(median))
plt.show()
# Out:
# Mean is 2013.0907834101383
# Median is 2014.0

# %%
sns.histplot(bike_df['cnt'])
mean = bike_df['cnt'].mean()
median = bike_df['cnt'].median()
print("Mean is {}".format(mean))
print("Median is {}".format(median))
plt.show()
# Out:
# Mean is 189.46308763450142
# Median is 142.0

# %%
sns.histplot(np.log(bike_df['cnt']))
mean = np.log(bike_df['cnt']).mean()
median = np.log(bike_df['cnt']).median()
print("Mean is {}".format(mean))
print("Median is {}".format(median))
plt.show()
# Out:
# Mean is 4.536082104443518
# Median is 4.955827057601261

# %% [markdown]
# ### Bargraphs
#
# <li>A bar graph can be defined as a graphical representation of data, quantities, or numbers using bars or strips.</li>
# <li>They are used to compare and contrast different types of data, frequencies, or other measures of distinct categories of data.</li>
#
# **Elements of a Bar Graph**
#
# <li><b>1. Bars</b></li>
# <li>The rectangles drawn on the bar charts are called “bars”.</li>
# <li>The bars display the number of items under particular categories.</li>
#
# <li><b>2. Axes</b></li>
# <li>There are two axes present on the graph.</li>
# <li>One axis is used to represent the numerical values whereas the other represents the categorical data against which the numerical data is plotted.</li>
#
# ![](images/bar_graph.png)

# %% [markdown]
# <li>We often use barplots while doing univariate analysis of a categorical feature.</li>
# <li>Barplots are often referred as a visual representaion of a frequency table.</li>
# <li>We can generate a bar plot using the <b>plt.bar()</b> function</li>

# %%
season_df = pd.DataFrame({"season": ['Spring', "Summer", "Fall", "Winter"],
                         "No.of.students": [5, 12, 6, 10]})
season_df.head()
# Out:
#    season  No.of.students
# 0  Spring               5
# 1  Summer              12
# 2    Fall               6
# 3  Winter              10

# %%
plt.figure(figsize = (6,6))
plt.bar(season_df['season'], season_df['No.of.students'], color = ['red', 'green', 'purple', 'blue'],
       label = season_df['season'])
plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (6,6))
sns.barplot(data = season_df, x = 'season', y = 'No.of.students')
plt.show()

# %% [markdown]
# ## Customizing barplots
#
# <li>A minimum bargraph must have categories in x-axis and height of the graph in y-axis.</li>
# <li>We can add the title to the graph using <b>plt.title()</b>.</li>
# <li>Similarly, we can also add x-label and y-label to the graph using <b>plt.xlabel()</b> and <b>plt.ylabel()</b> function.</li>
# <li>You can also give color to each bars using <b>color</b> parameter in <b>plt.plot()</b> method.</li>
# <li>Additionally, you can also supply <b>label</b> parameters to the <b>plt.plot()</b> method.</li>
# <li>You can also add legend to the barplots using <b>plt.legend()</b> but you must supply label parameter in <b>plt.plot()</b> method.</li>
# <li>We can also create horizontal bargraph using <b>plt.barh()</b></li>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
company_df = pd.read_csv('csv_data/Fortune_1000.csv')
company_df.head()
# Out:
#               company  rank  rank_change   revenue   profit  \
# 0             Walmart     1          0.0  572754.0  13673.0
# 1              Amazon     2          0.0  469822.0  33364.0
# 2               Apple     3          0.0  365817.0  94680.0
# 3          CVS Health     4          0.0  292111.0   7910.0
# 4  UnitedHealth Group     5          0.0  287597.0  17285.0
#
#    num. of employees       sector         city state newcomer ceo_founder  \
# 0          2300000.0    Retailing  Bentonville    AR       no          no
# 1          1608000.0    Retailing      Seattle    WA       no          no
# 2           154000.0   Technology    Cupertino    CA       no          no
# 3           258000.0  Health Care   Woonsocket    RI       no          no
# 4           350000.0  Health Care   Minnetonka    MN       no          no
#
#   ceo_woman profitable prev_rank                  CEO  \
# 0        no        yes       1.0  C. Douglas McMillon
# ...

# %%
sector_df = company_df['sector'].value_counts().to_frame().reset_index()
sector_df.columns = ['sector', 'frequency']
sector_df.head()
# Out:
#         sector  frequency
# 0   Financials        166
# 1   Technology        121
# 2       Energy        100
# 3    Retailing         77
# 4  Health Care         77

# %%
sector_df.isnull().sum()
# Out:
# sector       0
# frequency    0
# dtype: int64

# %%
plt.figure(figsize = (30, 10))
plt.bar(sector_df['sector'], sector_df['frequency'])
plt.title('Sectorwise Distribution of Fortune 1000 Companies')
plt.xlabel('Sectors')
plt.xticks(rotation = 20)
plt.ylabel('No of companies')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (30, 10))
sns.barplot(data = sector_df, x = 'sector', y = 'frequency')
plt.title('Sectorwise Distribution of Fortune 1000 Companies')
plt.xlabel('Sectors')
plt.xticks(rotation = 20)
plt.ylabel('No of companies')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (10, 10))
plt.barh(sector_df['sector'], sector_df['frequency'])
plt.title('Sectorwise Distribution of Fortune 1000 Companies')
plt.xlabel('Sectors')
plt.xticks(rotation = 20)
plt.ylabel('No of companies')
plt.show()

# %%
def freq_count_df(df, col_name, renamed_cols):
    new_df = df[col_name].value_counts().to_frame().reset_index()
    new_df.columns = renamed_cols
    return new_df

# %%
def univariate_bargraph(df, figsize, title, xlabel, ylabel):
    
    columns = list(df.columns)
    plt.figure(figsize = figsize)
    plt.bar(df[columns[0]], df[columns[1]])
    plt.title(title)
    plt.xlabel(xlabel)
    plt.xticks(rotation = 10)
    plt.ylabel(ylabel)
    plt.show()

# %%
new_comer_df = freq_count_df(company_df, 'newcomer',
                             ['new_comer', 'frequency'])
new_comer_df.head()
# Out:
#   new_comer  frequency
# 0        no        970
# 1       yes         30

# %%
univariate_bargraph(new_comer_df, (10, 6),
                    title = "Distribution of New comers in Fortune 1000 companies",
                   xlabel = 'New Comer', ylabel = 'No of Companies')

# %%
car_df = pd.read_csv('csv_data/car_details.csv')
car_df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
ownertype_df = freq_count_df(car_df, 'owner', ['owner', 'frequency'])
ownertype_df.head()
# Out:
#                   owner  frequency
# 0           First Owner       2832
# 1          Second Owner       1106
# 2           Third Owner        304
# 3  Fourth & Above Owner         81
# 4        Test Drive Car         17

# %%
univariate_bargraph(ownertype_df, (10, 6),
                    title = "Distribution of Owner Types",
                   xlabel = 'Owner Types', ylabel = 'No of Cars')

# %%
def univariate_barplot(df, title, xlabel, ylabel, figsize):

    plt.figure(figsize=figsize)
    columns = list(df.columns)
    ax = sns.barplot(x=columns[0],y=columns[1],data = df)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    for value in ax.patches:
        ax.text(value.get_x(), value.get_height() + 10, value.get_height())
    plt.show()

# %%
sellertype_df = freq_count_df(car_df, 'seller_type', ['seller_type', 
                                                      'frequency'])
sellertype_df.head()
# Out:
#         seller_type  frequency
# 0        Individual       3244
# 1            Dealer        994
# 2  Trustmark Dealer        102

# %%
univariate_barplot(sellertype_df, title = "Distribution of seller types",
                   xlabel = "Seller Types",
                   ylabel =  "Frequency", figsize = (12, 8))

# %% [markdown]
# ### Difference Between Histogram & BarGraphs
#
# ![](images/fig_hist_vs_bargraph.png)
# ![](images/histograph_vs_barplot.png)

# %% [markdown]
# ## Piecharts
# <li>Piecharts are the type of graphs in which a circle is divided into sectors that each represent a proportion of the whole.</li>
# <li>Pie charts can be used to show percentages of a whole, and represents percentages at a set point in time.</li>
# <li>Unlike bar graphs and line graphs, pie charts do not show changes over time.</li>
# <li>With matplotlib, you can use the </b>pie()</b> function to draw pie charts.</li>
# <li>Inside plt.pie() there are several parameters:</li>
# <ol>
#     <li>numpy_array -> freq dist of a column</li>
#     <li>labels = categorical values</li>
#     <li>explode = highlight certain portion</li>
#     <li>autopct = lambda p: '{:.1f}%' -> write values inside a piechart.</li>
# </ol>

# %%
import numpy as np
data = np.array([12, 45, 43, 87, 22, 43])
labels = ['a','b', 'c', 'd', 'e', 'f']
myexplode = [0, 0, 0, 0, 0.4, 0]
plt.pie(x = data, labels = labels, explode = myexplode)
plt.legend()
plt.show()

# %%
fuel_df = freq_count_df(car_df, 'fuel', ['fuel', 'frequency'])
fuel_df.head()
# Out:
#        fuel  frequency
# 0    Diesel       2153
# 1    Petrol       2123
# 2       CNG         40
# 3       LPG         23
# 4  Electric          1

# %%
# labels = ['a','b', 'c', 'd', 'e', 'f']
# myexplode = [0, 0, 0, 0, 0.4, 0]
plt.pie(x = fuel_df['frequency'])

plt.legend(fuel_df['fuel'])
plt.show()

# %%
women_ceo_df = freq_count_df(company_df, 'ceo_woman', ['ceo_woman', 'frequency'])
women_ceo_df.head()
# Out:
#   ceo_woman  frequency
# 0        no        917
# 1       yes         83

# %%
myexplode = [0.25, 0]
plt.pie(x = women_ceo_df['frequency'], labels = women_ceo_df['ceo_woman'],
       explode = myexplode, colors = ['green', 'red'],
       autopct = '%.2f')
plt.legend()
plt.show()

# %%
women_ceo_df['frequency'].plot(kind = 'pie', autopct = "%.2f%%",
                              colors = ['red', 'green'], explode = [0.25, 0],
                              shadow= True, startangle = 45,
                            )
# Out:
# <AxesSubplot: ylabel='frequency'>

# %% [markdown]
# ## BoxPlots
# <li>In descriptive statistics, a box plot or boxplot (also known as box and whisker plot) is a type of chart often used in explanatory data analysis.</li>
# <li>Box plots visually show the distribution of numerical data and skewness through displaying the data quartiles (or percentiles) and averages.</li>
# <li>A Box Plot is also known as Whisker plot is created to display the summary of the set of data values.</li>
# <li>The summary includes the properties like minimum, first quartile, median, third quartile and maximum.</li>
# <li>The matplotlib.pyplot module of matplotlib library provides boxplot() function with the help of which we can create box plots.</li>
# <li>Box plots help visualize the distribution of quantitative values in a field.</li>
#
# ![](images/boxplot.png)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = [3,54,64,21,43,65,43,42,54,23,22,34,67,65,98,99,43,19,26,34,450,150,250,350,100]

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2411bf0cf70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2411bf1b3d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2411bf0ccd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2411bf1b910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2411bf1bbb0>],
#  'means': []}

# %%
sns.boxplot(data)
# Out:
# <AxesSubplot: >

# %%
car_df = pd.read_csv('csv_data/car_details.csv')
car_df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
sns.boxplot(car_df['km_driven'])
# Out:
# <AxesSubplot: >

# %%
plt.boxplot(car_df['km_driven'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2411d03c5e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2411d03cb20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2411d03c340>],
#  'medians': [<matplotlib.lines.Line2D at 0x2411d0540a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2411d054340>],
#  'means': []}

# %%
plt.boxplot(car_df['selling_price'])
plt.yticks(rotation = 10)
plt.show()

# %% [markdown]
# ## Bivariate & Multivariate Analysis
#
# <li><b>Bivariate analysis</b> refers to the analysis of two variables to determine relationships between them.</li>
# <li><b>Bivariate analysis</b> explores how the dependent (“outcome”) variable depends or is explained by the independent (“explanatory”) variables.</li>
# <li>If you are going to study the relationship between speeding and accident severity then such type of study comes under <b>bivariate analysis.</b></li>
# <li>We can use <b>scatter plots</b>, <b>correlation heatmaps</b> between two variables and stacked bargraphs to perform bivariate analysis of the group.</li>
#
# <li><b>Multivariate analysis</b> is one of the most useful methods to determine relationships and analyse patterns among large sets of data.</li>
# <li><b>Multivariate analysis</b> is used to measure the effect of multiple independent variables on two or more dependent variables.</li>
# <li>We can use pairplots, relation plots and correlation heatmaps between multiple variables to perform multivariate analysis of the group.</li>

# %% [markdown]
# ### Scatter Plots
#
# <li>Scatter Plot is a graph in which the values of two variables are plotted along two axes.</li>
# <li>The pattern of the resulting points in a scatter plot reveals any correlation present between two data points.</li>
# <li>Continuous data allows you to measure things in-depth on an infinite set. It’s commonly used for scattering analysis.</li>
# <li>In matplotlib, we can use scatterplot using the <b>plt.scatter()</b> method.</li>

# %%
plt.figure(figsize = (8,6))
plt.scatter(x = car_df['km_driven'], y = car_df['selling_price'])
plt.title("Km Driven Vs Selling Price")
plt.xlabel("Km Driven")
plt.ylabel("Selling Price")
plt.ticklabel_format(style = 'plain')
plt.show()

# %%
car_df['brand'] = car_df['name'].str.strip().str.split(' ').str[0].str.strip()

# %%
tata_df = car_df.loc[car_df['brand'] == "Tata"]

# %%
plt.figure(figsize = (10,8))
plt.scatter(x = tata_df['km_driven'], y = tata_df['selling_price'])
plt.title("Km Driven Vs Selling Price For Tata Cars")
plt.xlabel("Km Driven")
plt.ylabel("Selling Price")
plt.ticklabel_format(style = 'plain')
plt.show()

# %% [markdown]
# ## Question
# <li>Generate a scatter plot with the windspeed column on the x-axis and the cnt column on the y-axis. Use the <b>plt.scatter()</b>function.</li>
# <li>Add the <b>'Wind Speed'</b> x-axis label using <b>plt.xlabel().</b></li>
# <li>Add the <b>'Bikes Rented'</b> y-axis label using <b>plt.ylabel().</b></li>
# <li>Display the plot using <b>plt.show().</b></li>

# %%
bike_df = pd.read_csv('csv_data/bike_rental_datasets.csv')
bike_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bike_df['dteday'] = pd.to_datetime(bike_df['dteday'])
bike_df.set_index('dteday', inplace = True)
bike_df.head()
# Out:
#             instant  season  yr  mnth  hr  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1   0        0        6           0
# 2011-01-01        2       1   0     1   1        0        6           0
# 2011-01-01        3       1   0     1   2        0        6           0
# 2011-01-01        4       1   0     1   3        0        6           0
# 2011-01-01        5       1   0     1   4        0        6           0
#
#             weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# dteday
# 2011-01-01           1  0.24  0.2879  0.81        0.0       3          13   16
# 2011-01-01           1  0.22  0.2727  0.80        0.0       8          32   40
# 2011-01-01           1  0.22  0.2727  0.80        0.0       5          27   32
# 2011-01-01           1  0.24  0.2879  0.75        0.0       3          10   13
# 2011-01-01           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bike_df = bike_df.resample('D').mean()

# %%
plt.figure(figsize = (10, 8))
plt.scatter(bike_df['windspeed'], bike_df['cnt'])
plt.xlabel("Wind Speed")
plt.ylabel("Bikes Rented")
plt.show()

# %% [markdown]
# ## Question
# <li>Generate a scatter plot with the temp column on the x-axis and the registered column on the y-axis. Use the <b>plt.scatter()</b>function.</li>
# <li>Add the <b>'Temperature'</b> x-axis label using <b>plt.xlabel().</b></li>
# <li>Add the <b>'Bikes Rented'</b> y-axis label using <b>plt.ylabel().</b></li>
# <li>Display the plot using <b>plt.show().</b></li>

# %%
plt.figure(figsize = (10, 8))
plt.scatter(bike_df['temp'], bike_df['registered'])
plt.xlabel("Temperature")
plt.ylabel("Bikes Rented")
plt.show()

# %% [markdown]
# ## Correlation
#
# <li>When two columns are statistically related in a specific way and to a certain degree, we call this relationship <b>correlation.</b></li>
#
# <li>There are two kinds of correlation:</li>
# <ol>
#     <li><b>Positive correlation</b></li>
#     <li><b>Negative correlation</b></li>
# </ol>
#
# <b>1. Positive Correlation</b>
#
# <li>Two positively correlated columns tend to change in the same direction. When one increases,the other tends to increaseas well.</li>
# <li>When one decreases, other tends to decrease as well.</li>
# <li>On a scatter plot, two positively correlated columns show an upward trend.</li>
#
# ![](images/pos_corr.png)
#
# <b>2. Negative Correlation</b>
#
# <li>Two negatively correlated columns tend to change in opposite directions.</li>
# <li>When one increases, the other tends to decrease, and vice versa.</li>
# <li>On a scatter plot, two negatively correlated columns show a downward trend.</li>
#
# ![](images/neg_corr.png)

# %% [markdown]
# ### Pearson's Correlation Coefficient
#
# <li>The most popular way to measure correlation strength is by calculating the degree to which the points on a scatter plot fit on a straight line.</li>
#
# <li>We can measure how well the points fit on a straight line by using the Pearson correlation coefficient.</li>
# <li>Pearson's correlation coefficient values lie between -1.00 and +1.00.</li>
# <li>When the positive correlation is perfect, the Pearson's correlation coefficient value is equal to +1.00.</li>
# <li>When the negative correlation is perfect, the Pearson's correlation coefficeint value is equal to -1.00.</li>
# <li>A value of 0.0 shows no correlation.</li>
# <li>When we compare correlation strengths, we need to ignore the signs and only look at the absolute r values.</li>
# <li>The sign only gives us the correlation's direction, not its strength.</li>
#
# ![](images/corr_types.png)

# %% [markdown]
# ## Measuring Correlation
# <li>We can measure the correlation between any numeric columns using df.corr() method.</li>
# <li>But if you are interested in visualizing the correlation maps between any numeric columns, you can use seaborn heatmaps.</li>
# <li><b>Heatmaps</b> are a representation of data in the form of a map or diagram in which data values are represented as colours.</li>
# <li>For creating a heatmap, you need to use <b>sns.heatmap()</b> method with the following sets of parameters:</li>
# <ol>
#     <li>df -> a dataframe containing correlation value.</li>
#     <li>annot = True or False. If you want to see the corr value inside the figure then use annot = True else False.</li>
#     <li>fmt = '.1f' / '.2f' -> Its value depends on how many digits you should consider after floating value since correlation coefficient is a float value.</li>
#     <li>You can specify color to the heatmap using cmap value which refers to color map.</li>
#     <li>cmap = "Blues", "coolwarm", "cool", "hot", "rainbow", "flag" are some values of cmap.</li>
#     <li>cbar = True or False -> Depends on whether or you want a color bar.</li>
# </ol>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
car_df.corr()
# Out:
#                    year  selling_price  km_driven
# year           1.000000       0.413922  -0.419688
# selling_price  0.413922       1.000000  -0.192289
# km_driven     -0.419688      -0.192289   1.000000

# %%
sns.heatmap(car_df.corr(), annot = True, fmt = '.4f', cmap = 'coolwarm',
           cbar = True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Question
#
# <li>Calculate the Pearson's r between the temp and atemp columns. Assign your answer to temp_atemp_corr.</li>
# <li>Calculate the Pearson's r between the windspeed and hum columns. Assign your answer to wind_hum_corr.</li>
# <li>Generate a scatter plot with the temp column on the x-axis and the atemp column on the y-axis.</li>
# <li>Add 'Feeling Temperature' as an x-label.</li>
# <li>Add 'Air Temperature' as an y-label.</li>
# <li>Generate a scatter plot with the windspeed column on the x-axis and the hum column on the y-axis.</li>
# <li>Add 'Wind Speed' as an x-label.</li>
# <li>Add 'Humidity' as an y-label.</li>

# %%
temp_atemp_corr = bike_df[['temp', 'atemp']].corr()
print(temp_atemp_corr)
# Out:
#            temp     atemp
# temp   1.000000  0.991702
# atemp  0.991702  1.000000

# %%
wind_hum_corr = bike_df[['windspeed', 'hum']].corr()
print(wind_hum_corr)
# Out:
#            windspeed       hum
# windspeed   1.000000 -0.248489
# hum        -0.248489  1.000000

# %%
plt.scatter(bike_df['temp'], bike_df['atemp'])
plt.xlabel("Feeling Temperature")
plt.ylabel('Air Temperature')
plt.title('Air Temperature Vs Feeling Temperature')
# Out:
# Text(0.5, 1.0, 'Air Temperature Vs Feeling Temperature')

# %%
plt.scatter(bike_df['windspeed'], bike_df['hum'])
plt.xlabel("Windspeed")
plt.ylabel('Humidity')
plt.title('Windspeed Vs Humidity')
# Out:
# Text(0.5, 1.0, 'Windspeed Vs Humidity')

# %%
plt.figure(figsize = (10, 6))
plt.subplot(1, 2, 1)
plt.scatter(bike_df['temp'], bike_df['atemp'])
plt.xlabel("Feeling Temperature")
plt.ylabel('Air Temperature')
plt.title('Air Temperature Vs Feeling Temperature')
plt.subplot(1, 2, 2)
plt.scatter(bike_df['windspeed'], bike_df['hum'])
plt.xlabel("Windspeed")
plt.ylabel('Humidity')
plt.title('Windspeed Vs Humidity')
# Out:
# Text(0.5, 1.0, 'Windspeed Vs Humidity')

# %% [markdown]
# ## Customization Of Scatter Plots
#
# <li>For customizing a scatterplot, you can specify the colors to each of the dependent feature column.</li>
# <li>We can use seaborn and matplotlib both to give beautiful customization to our scatterplots.</li>
# <li>If we use matplotlib, we have to create multiple scatterplots for each of the category and give separate color and label to each category to distinguish them.</li>
# <li>In matplotlib, you can give color to each scatterplot using color parameter and you can also pass label parameter to give class name.</li>
# <li>Incase of seaborn, you can pass <b>hue</b> parameter to the category you want to separate the plots with.</li>
# <li>Example, If you are plotting age vs bmi relationships in a scatterplot and then you want to separate it with healthy and sick category, you can specify <b>health_condition</b> column as a <b>hue</b> parameter.</li>
#
# <code>
#     sns.scatterplot(data = df, x = 'age', y = 'bmi', hue = 'health_condition', palette = ['red','green']
# </code>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_df = pd.read_csv('csv_data/Iris.csv')
print(iris_df.shape)
iris_df.head()
# Out:
# (150, 6)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris1 = iris_df.loc[iris_df['Species'] == "Iris-setosa"]
iris2 = iris_df.loc[iris_df['Species'] == "Iris-versicolor"]
iris3 = iris_df.loc[iris_df['Species'] == "Iris-virginica"]

# %%
plt.figure(figsize = (8, 6))
plt.scatter(x = iris1['SepalLengthCm'], 
           y = iris1['SepalWidthCm'], color = 'red', label = "Iris-setosa")
plt.scatter(x = iris2['SepalLengthCm'], 
           y = iris2['SepalWidthCm'], color = 'green', 
            label = "Iris-versicolor")
plt.scatter(x = iris3['SepalLengthCm'], 
           y = iris3['SepalWidthCm'], color = 'blue', 
            label = "Iris-virginica")
plt.title("Iris Flowers Based ON Sepal Length Vs Sepal Width")
plt.xlabel("Sepal Length In Cm")
plt.ylabel("Sepal Width In Cm")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.scatter(x = iris1['PetalLengthCm'], 
           y = iris1['PetalWidthCm'], color = 'red', label = "Iris-setosa")

plt.scatter(x = iris2['PetalLengthCm'], 
           y = iris2['PetalWidthCm'], color = 'green', 
            label = "Iris-versicolor")

plt.scatter(x = iris3['PetalLengthCm'], 
           y = iris3['PetalWidthCm'], color = 'blue', 
            label = "Iris-virginica")

plt.title("Iris Flowers Based ON Petal Length Vs Petal Width")
plt.xlabel("Petal Length In Cm")
plt.ylabel("Petal Width In Cm")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8, 6))
sns.scatterplot(data = iris_df, x = 'SepalLengthCm', y = "PetalLengthCm", 
               hue = "Species", palette = ["red", "green", "blue"])
plt.title("Iris Flowers Based On Sepal Length Vs Petal Length")
plt.show()

# %%
car_df = pd.read_csv('csv_data/car_details.csv')
car_df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
plt.figure(figsize = (8, 6))
sns.scatterplot(data = car_df, x = 'km_driven', y = 'selling_price', hue = 'owner',
               palette = ['red', 'green', 'blue', 'orange', 'black'])
plt.show()

# %%
car_df['owner'].value_counts()
# Out:
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %% [markdown]
# ## Bivariate Barplots
#
# <li>If we want to study the frequency distribution of independent column with respect to dependent column, then we use multivariate barplots.</li>
# <li>We need to use pd.crosstab() method to calculate the frequency distribution of independent column with respect to dependent column.</li>
# <li>Then we can create a stacked barplot to show the multivariate relation that exists between them.</li>
#
# **syntax**
#
# <code>
#     df.plot(kind = 'bar', stacked = True, color)
# </code>

# %%
company_df = pd.read_csv('csv_data/Fortune_1000.csv')
company_df.head()
# Out:
#               company  rank  rank_change   revenue   profit  \
# 0             Walmart     1          0.0  572754.0  13673.0
# 1              Amazon     2          0.0  469822.0  33364.0
# 2               Apple     3          0.0  365817.0  94680.0
# 3          CVS Health     4          0.0  292111.0   7910.0
# 4  UnitedHealth Group     5          0.0  287597.0  17285.0
#
#    num. of employees       sector         city state newcomer ceo_founder  \
# 0          2300000.0    Retailing  Bentonville    AR       no          no
# 1          1608000.0    Retailing      Seattle    WA       no          no
# 2           154000.0   Technology    Cupertino    CA       no          no
# 3           258000.0  Health Care   Woonsocket    RI       no          no
# 4           350000.0  Health Care   Minnetonka    MN       no          no
#
#   ceo_woman profitable prev_rank                  CEO  \
# 0        no        yes       1.0  C. Douglas McMillon
# ...

# %%
company_df['ceo_woman'].value_counts()
# Out:
# no     917
# yes     83
# Name: ceo_woman, dtype: int64

# %%
company_df['profitable'].value_counts()
# Out:
# yes    883
# no     117
# Name: profitable, dtype: int64

# %%
profitable_df = company_df.loc[company_df['profitable'] == 'yes', 'ceo_woman'].value_counts().to_frame().reset_index()
profitable_df.columns = ['ceo_woman', 'no_of_profitable_companies']
profitable_df.head()
# Out:
#   ceo_woman  no_of_profitable_companies
# 0        no                         808
# 1       yes                          75

# %%
non_profitable_df = company_df.loc[company_df['profitable'] == 'no', 'ceo_woman'].value_counts().to_frame().reset_index()
non_profitable_df.columns = ['ceo_woman', 'no_of_non_profitable_companies']
non_profitable_df.head()
# Out:
#   ceo_woman  no_of_non_profitable_companies
# 0        no                             109
# 1       yes                               8

# %%
profit_df = pd.merge(profitable_df, non_profitable_df, on = "ceo_woman", how = "inner")
profit_df.head()
# Out:
#   ceo_woman  no_of_profitable_companies  no_of_non_profitable_companies
# 0        no                         808                             109
# 1       yes                          75                               8

# %%
plt.figure(figsize = (8, 6))
plt.bar(x= profit_df['ceo_woman'], height = profit_df['no_of_profitable_companies'],
        color = 'blue', label = 'profit')
plt.bar(x = profit_df['ceo_woman'], height = profit_df['no_of_non_profitable_companies'],
        color= 'red', label = 'non profit')
plt.legend()
plt.xlabel('Women As A CEO Of A Company')
plt.ylabel("NO of Companies")
plt.show()

# %%
profit_df2 = pd.crosstab(company_df['ceo_woman'], company_df['profitable'])
profit_df2.head()
# Out:
# profitable   no  yes
# ceo_woman
# no          109  808
# yes           8   75

# %%
profit_df2.plot(kind = 'bar', stacked = True, color = ['blue', 'red'])
# Out:
# <AxesSubplot: xlabel='ceo_woman'>

# %% [markdown]
# ## Bivariate KDE Plot
#
# <li>A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analogous to a histogram.</li>
# <li>Kdeplot is a Kernel Distribution Estimation Plot which depicts the probability density function of the continuous or non-parametric data variables.</li>
# <li>We can plot for the univariate or multiple variables altogether.</li>
# <li>For creating a bivariate KDE plot, you have to create separate dataframe belonging to a particular class or category like we did in linecharts.</li>
# <li>Then you can create multiple kde plots each for each category of class.</li>
# <li>You can provide separate label and separate color for each class for distinguishing each category of class.</li>
# <li>This way, we can figure out the data distribution of each category of class.</li>
#
# **Syntax**
#
# <code>
#     sns.kdeplot(df1, color, label)
#     sns.kdeplot(df2, color, label)
# </code>
#
# <li>Here df1 and df2 are two separate dataframes belonging to each category of class.</li>

# %%
plt.figure(figsize = (8, 6))
sns.kdeplot(iris1['SepalLengthCm'], color = 'red', label = 'Iris-setosa')
sns.kdeplot(iris2['SepalLengthCm'], color = 'green', label = 'Iris-versicolor')
sns.kdeplot(iris3['SepalLengthCm'], color = 'blue', label = 'Iris-virginica')
plt.title("KDE Plots For Different Iris Species Based ON Sepal Length Density")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8, 6))
sns.kdeplot(iris1['PetalLengthCm'], color = 'red', label = 'Iris-setosa')
sns.kdeplot(iris2['PetalLengthCm'], color = 'green', label = 'Iris-versicolor')
sns.kdeplot(iris3['PetalLengthCm'], color = 'blue', label = 'Iris-virginica')
plt.title("KDE Plots For Different Iris Species Based ON Petal Length Density")
plt.legend()
plt.show()

# %% [markdown]
# ### Pairplots
#
# <li>A pairplot plot a pairwise relationships in a dataset.</li>
# <li>The pairplot creates a grid of axes such that each variable in data will be shared in the y-axis across a single row and in the x-axis across a single column.</li>
# <li>To plot multiple pairwise bivariate distributions in a dataset, you can use the .pairplot() function.</li>
#
# **Syntax**
#
# <code>
#     sns.pairplot(df, hue = dependent_column)
# </code>

# %%
clean_iris_df = iris_df.drop('Id', axis = 1)
clean_iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(clean_iris_df, hue = 'Species')

# %% [markdown]
# ### Relation Plots
# <li>The Seaborn Relational Plot (relplot) allows us to visualise how variables within a dataset relate to each other.</li>
# <li>Relational plots are used for visualizing the statistical relationship between the data points.</li>
# <li>We can visualize the relation plots in a seaborn library using sns.relplot()</li>
#
# **Syntax**
#
# <code>
# sns.relplot(x, y, data, hue, row, col)
# </code>

# %%
titanic_df = pd.read_csv('csv_data/titanic.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df['Sex'] = titanic_df['Sex'].replace({"female": 0, "male": 1})
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
sns.relplot(x = "Age", y = "Fare", data = titanic_df,  hue = 'Survived', row = "Sex", col = "Pclass")
plt.show()

# %% [markdown]
# ## 3D Plots Using Plotly
# <li>3D scatter plots are used to plot data points on three axes in the attempt to show the relationship between three variables.</li>
# <li>Each row in the data table is represented by a marker whose position depends on its values in the columns set on the X, Y, and Z axes.</li>
# <li>We can get better 3d visualizations with plotly library.</li>
#
# **Syntax**
#
# <code>
#     px.scatter_3d(data, x, y, z, color)
# </code>

# %% [markdown]
# ## Working with images in matplotlib
#
# <li>imread() is a function provided by the matplotlib.pyplot library, and is used to read an image and store it in the form of an array.</li>
#
# <code>
#     image = plt.imread(img_path)
#     plt.imshow(image)
# </code>
